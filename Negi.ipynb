# %%
pip install -r requirements.txt
# Out:
# ...
#   Using cached google_api_python_client-2.108.0-py2.py3-none-any.whl.metadata (6.6 kB)
# ...
#   Using cached httplib2-0.22.0-py3-none-any.whl (96 kB)
# ...
#   Using cached google_auth-2.23.4-py2.py3-none-any.whl.metadata (4.7 kB)
# ...
#   Using cached google_auth_httplib2-0.1.1-py2.py3-none-any.whl.metadata (2.1 kB)
# ...
#   Using cached google_api_core-2.14.0-py3-none-any.whl.metadata (2.6 kB)
# ...
#   Using cached uritemplate-4.1.1-py2.py3-none-any.whl (10 kB)
# ...
#   Using cached googleapis_common_protos-1.61.0-py2.py3-none-any.whl.metadata (1.5 kB)
# ...
#   Using cached protobuf-4.25.1-cp310-abi3-win_amd64.whl.metadata (541 bytes)
# ...
#   Using cached cachetools-5.3.2-py3-none-any.whl.metadata (5.2 kB)
# ...
#   Using cached pyasn1_modules-0.3.0-py2.py3-none-any.whl (181 kB)
# ...
#   Using cached rsa-4.9-py3-none-any.whl (34 kB)
# ...
#   Using cached pyparsing-3.1.1-py3-none-any.whl.metadata (5.1 kB)
# ...
#   Using cached pyasn1-0.5.1-py2.py3-none-any.whl.metadata (8.6 kB)
# ...

# %%
import googleapiclient
import pprint
import pandas as pd
from src.crawl import YTService
from googleapiclient.http import HttpRequest
from googleapiclient.discovery import build
from src.crawl import utils

# %%
 youtube = googleapiclient.discovery.build(
        'youtube', 'v3', developerKey = 'AIzaSyBVzTqpCARphnPnYdyPmE7gEmVK1Ab8Jco')

# %%
# api_key: AIzaSyClWdnNiQZbkXG_0bv55t1vUPsQlDq63BI #1 maitho
#          AIzaSyBVzTqpCARphnPnYdyPmE7gEmVK1Ab8Jco #2 negi_2
#          AIzaSyD1CGatPTGh1JjvpJH68pJo8EYdHduoPp8 #3 negi_1
# channel_id = 'UCaIrY40rwEf51POKMybW-Eg' #lanlinh_channel

# %%
#Get all videos of channel

limit = 10
response_total = {}
response_temp = {}
nextpagetoken = ""
for i in range(limit):
        request_video = youtube.search().list(
                part="snippet",
                channelId="UCaIrY40rwEf51POKMybW-Eg",
                maxResults=50,
                order="date",
                pageToken = nextpagetoken
            )
        response_temp = request_video.execute()
        if i == 0:
            response_total = response_temp
        else:
            response_total['items'] += response_temp['items']
        if 'nextPageToken' in response_temp:
            nextpagetoken = response_temp['nextPageToken']
        else:
            break

# %%
video_ids = [] #append to list video_ids
for item in response_total['items']:
    if item['id']['kind'] == 'youtube#video':
        video_id = str(item['id']['videoId'])
        video_ids.append(video_id)

# %%
video_ids #list video_ids
# Out:
# ['dE2nDuo2iNo',
#  'ZXe5JVBb2Fw',
#  'zedZbEnK6yw',
#  'xxfU5lI4O-A',
#  'TlcqnaQZmFY',
#  'NhNGmw_16nc',
#  'EkGqkSFkdX4',
#  'goAErZ-Fl64',
#  'nm8bdqkSkLc',
#  'hGHPUYszShU',
#  'z1bP4-VRHCY',
#  '9sd2LIHtdLY',
#  'ZmNz3WFTmuA',
#  'JLq958BgMfs',
#  'Qpz-YahDyXQ',
#  'R_Jm8kSbR1o',
#  'H2XST6tQ_xM',
#  '6veVBB4DbPk',
#  'mVZd5Mo-fuM',
#  '2pGRxdUp1eM',
#  'EmhSAiiRlIo',
#  'B4uZYtpWYhU',
#  'AvnBhgTGkK4',
#  '4TAqUeZQ1og',
#  'XP8TFx-fPsM',
#  'pW7eWI0IQWg',
#  'd2P7zvm9PyI',
#  '3k3J5dGlvQQ',
#  'tmhFTAXkzbY',
#  'uu6DfGS1_xQ',
#  'UQPc4mhCh94',
#  'zUHez4LXRpk',
#  'dliIA-752Uo',
#  'ysd48olX8bA',
#  'T_sw6RhnQRU',
#  'CGrpRewfJG0',
#  '0TAJXm6zF9A',
#  'CW5NZUuSruQ',
#  'DwnkYW5q7Fw',
#  'He8EDr2K5rE',
#  '9DenFJA1juY',
#  'zZLstTyAB2I',
#  'm5HLezZRDmg',
#  'N5hgyERw6cY',
#  'gEayaHdwtAQ',
#  '65WVgpoowOU',
#  'dCBPhoP5eW8',
#  'W_aN38_CMXw',
#  'LgS45tUiy3k',
#  'WxW3lZ8vrBU',
#  'Pij5g5vrE1Y',
#  '-u-gcfHu-Bs',
#  'iIokrKIg26M',
#  'b0aifYKCxug',
#  'aFEfqocBZfQ',
# ...

# %%
# Create blank dataframe to store details information of videos
df_video = pd.DataFrame(columns=['Video_ID','Channel_ID', 'Video_Title', 'Published_At', 'Thumbnails', 'Comments', 'Likes', 'Views', 'Duration', 'Start_Time', 'End_Time', 'Scheduled_Time', 'Topic_Category'])
df_video
# Out:
# Empty DataFrame
# Columns: [Video_ID, Channel_ID, Video_Title, Published_At, Thumbnails, Comments, Likes, Views, Duration, Start_Time, End_Time, Scheduled_Time, Topic_Category]
# Index: []

# %%
# Get details information of videos

for i, videos in enumerate(video_ids):
    try:
        request_vd_detail = youtube.videos().list(
            part="snippet, statistics, contentDetails, liveStreamingDetails, topicDetails",
            id=videos,
            maxResults=50
        )
        video_detail = request_vd_detail.execute()

        # Extract data from the API response
        snippet = video_detail['items'][0]['snippet']
        statistics = video_detail['items'][0]['statistics']
        content_details = video_detail['items'][0]['contentDetails']
        live_streaming_details = video_detail['items'][0].get('liveStreamingDetails', {})
        topic_details = video_detail['items'][0].get('topicDetails', {})

        # Extract fields
        Video_ID = video_detail['items'][0]['id']
        Channel_ID = snippet['channelId']
        Video_Title = snippet['title']
        Published_At = snippet['publishedAt']
        Thumbnails = snippet['thumbnails']['default']['url']
        Comments = statistics.get('commentCount', 0)
        Likes = statistics.get('likeCount', 0)
        Views = statistics.get('viewCount', 0)
        Duration = content_details['duration']
        Start_Time = live_streaming_details.get('actualStartTime', '')
        End_Time = live_streaming_details.get('actualEndTime', '')
        Scheduled_Time = live_streaming_details.get('scheduledStartTime', '')
        Topic_Category = topic_details.get('topicCategories', '')

        # Create row and add to DataFrame
        row = [Video_ID, Channel_ID, Video_Title, Published_At, Thumbnails, Comments, Likes, Views, Duration,
               Start_Time, End_Time, Scheduled_Time, Topic_Category]
        df_video.loc[i] = row

    except Exception as e:
        print(f"Error processing video {videos}: {e}")

# %%
df_video
# Out:
#         Video_ID                Channel_ID  \
# 0    dE2nDuo2iNo  UCaIrY40rwEf51POKMybW-Eg
# 1    ZXe5JVBb2Fw  UCaIrY40rwEf51POKMybW-Eg
# 2    zedZbEnK6yw  UCaIrY40rwEf51POKMybW-Eg
# 3    xxfU5lI4O-A  UCaIrY40rwEf51POKMybW-Eg
# 4    TlcqnaQZmFY  UCaIrY40rwEf51POKMybW-Eg
# ..           ...                       ...
# 207  Ggh6oh71pW4  UCaIrY40rwEf51POKMybW-Eg
# 208  7w_twiJ2QJw  UCaIrY40rwEf51POKMybW-Eg
# 209  id2yM2Kbb8g  UCaIrY40rwEf51POKMybW-Eg
# 210  8KPlFktdPy0  UCaIrY40rwEf51POKMybW-Eg
# 211  59LweghAqJQ  UCaIrY40rwEf51POKMybW-Eg
#
#                                            Video_Title          Published_At  \
# 0      Hành Trình Đến 30k Sub của Linh | NIKA LAN LINH  2023-11-19T17:29:38Z
# 1    Linh là vịt Lan là Ngõng | Goose Goose Duck | ...  2023-11-13T03:06:57Z
# 2    Chết Đói Cùng Kanon và Lan | Don't Starve Toge...  2023-11-11T14:21:12Z
# 3    Game Siêu Thử Thách... Die 1 Mạng Ăn 1 Củ Kiệu...  2023-11-11T02:02:01Z
# ...
